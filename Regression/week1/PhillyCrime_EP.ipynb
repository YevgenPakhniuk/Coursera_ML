# %% [markdown]
# #Fire up graphlab create

# %%
import pandas as pd

# %%
import numpy as np

# %%
sales = pd.read_csv('c://users/intel/Desktop/Coursera/Regression/week1/Philadelphia_Crime_Rate_noNA.csv')

# %%
sales_np = np.array(sales)

# %% [markdown]
# #Load some house value vs. crime rate data
#
# Dataset is from Philadelphia, PA and includes average house sales price in a number of neighborhoods.  The attributes of each neighborhood we have include the crime rate ('CrimeRate'), miles from Center City ('MilesPhila'), town name ('Name'), and county name ('County').

# %%
sales
# Out:
#     HousePrice  HsPrc ($10,000)  CrimeRate  MilesPhila  PopChg  \
# 0       140463          14.0463       29.7        10.0    -1.0
# 1       113033          11.3033       24.1        18.0     4.0
# 2       124186          12.4186       19.5        25.0     8.0
# 3       110490          11.0490       49.4        25.0     2.7
# 4        79124           7.9124       54.1        19.0     3.9
# 5        92634           9.2634       48.6        20.0     0.6
# 6        89246           8.9246       30.8        15.0    -2.6
# 7       195145          19.5145       10.8        20.0    -3.5
# 8       297342          29.7342       20.2        14.0     0.6
# 9       264298          26.4298       20.4        26.0     6.0
# 10      134342          13.4342       17.3        31.0     4.2
# 11      147600          14.7600       50.3         9.0    -1.0
# 12       77370           7.7370       34.2        10.0    -1.2
# 13      170822          17.0822       33.7        32.0     2.4
# ...

# %%
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #Exploring the data

# %%
print(type(sales[['HousePrice']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# The house price in a town is correlated with the crime rate of that town. Low crime towns tend to be associated with higher house prices and vice versa.

# %%
plt.scatter(sales_np[:, 0], sales_np[:, 2])

# %%
plt.show()

# %% [markdown]
# #Fit the regression model using crime as the feature

# %%
from sklearn import linear_model

# %%
help(linear_model)
# Out:
# Help on package sklearn.linear_model in sklearn:
#
# NAME
#     sklearn.linear_model
#
# DESCRIPTION
#     The :mod:`sklearn.linear_model` module implements generalized linear models. It
#     includes Ridge regression, Bayesian Regression, Lasso and Elastic Net
#     estimators computed with Least Angle Regression and coordinate descent. It also
#     implements Stochastic Gradient Descent related algorithms.
#
# PACKAGE CONTENTS
#     base
#     bayes
#     cd_fast
#     coordinate_descent
#     least_angle
#     logistic
#     omp
#     passive_aggressive
#     perceptron
#     randomized_l1
#     ransac
#     ridge
#     sag
#     sag_fast
#     setup
#     sgd_fast
#     stochastic_gradient
#     tests (package)
#     theil_sen
#
# CLASSES
#     sklearn.base.BaseEstimator(builtins.object)
# ...

# %%
help(linear_model.base.LinearRegression)
# Out:
# Help on class LinearRegression in module sklearn.linear_model.base:
#
# class LinearRegression(LinearModel, sklearn.base.RegressorMixin)
#  |  Ordinary least squares Linear Regression.
#  |
#  |  Parameters
#  |  ----------
#  |  fit_intercept : boolean, optional
#  |      whether to calculate the intercept for this model. If set
#  |      to false, no intercept will be used in calculations
#  |      (e.g. data is expected to be already centered).
#  |
#  |  normalize : boolean, optional, default False
#  |      If True, the regressors X will be normalized before regression.
#  |
#  |  copy_X : boolean, optional, default True
#  |      If True, X will be copied; else, it may be overwritten.
#  |
#  |  n_jobs : int, optional, default 1
#  |      The number of jobs to use for the computation.
#  |      If -1 all CPUs are used. This will only provide speedup for
#  |      n_targets > 1 and sufficient large problems.
#  |
#  |  Attributes
#  |  ----------
# ...

# %%
crime_model = linear_model.base.LinearRegression(fit_intercept=True)

# %%
type(np.array(sales[['CrimeRate']]))
# Out:
# numpy.ndarray

# %%
sales_feature = sales_np[:, np.newaxis, 2]

# %%
regr = crime_model.fit(sales_feature, sales_np[:, 0])

# %%
# The coefficients
print('Slope:', regr.coef_, '\nIntercept:', regr.intercept_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((regr.predict(sales_feature) - sales_np[:, 0]) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(sales_feature, sales_np[:, 0]))

# Plot outputs
plt.scatter(sales_feature, sales_np[:, 0],  color='black')
plt.plot(sales_feature, regr.predict(sales_feature), color='blue',
         linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Slope: [-576.90812768]
# Intercept: 176629.408107
# Residual sum of squares: 6967063954.55
# Variance score: 0.06

# %%
crime_model = graphlab.linear_regression.create(sales, target='HousePrice', features=['CrimeRate'],validation_set=None,verbose=False)

# %% [markdown]
# #Let's see what our fit looks like

# %% [markdown]
# Matplotlib is a Python plotting library that is also useful for plotting.  You can install it with:
#
# 'pip install matplotlib'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(sales['CrimeRate'],sales['HousePrice'],'.',
        sales['CrimeRate'],crime_model.predict(sales),'-')

# %% [markdown]
# Above: blue dots are original data, green line is the fit from the simple regression.

# %% [markdown]
# # Remove Center City and redo the analysis

# %% [markdown]
# Center City is the one observation with an extremely high crime rate, yet house prices are not very low.  This point does not follow the trend of the rest of the data very well.  A question is how much including Center City is influencing our fit on the other datapoints.  Let's remove this datapoint and see what happens.

# %%
sales_noCC = sales_np[sales_np[:, 3] != 0.0]

# %%
sales_np[:, 3]!= 0.0
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
plt.scatter(sales_noCC[:, 0], sales_noCC[:, 2])

# %%
plt.show()

# %% [markdown]
# ### Refit our simple regression model on this modified dataset:

# %%
crime_model_noCC = linear_model.base.LinearRegression()

# %%
sales_feature_noCC = sales_noCC[:, np.newaxis, 2]

# %%
regr_noCC = crime_model_noCC.fit(sales_feature_noCC, sales_noCC[:, 0])

# %%
# The coefficients
print('Slope:', regr_noCC.coef_, '\nIntercept:', regr_noCC.intercept_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((regr_noCC.predict(sales_feature_noCC) - sales_noCC[:, 0]) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr_noCC.score(sales_feature_noCC, sales_noCC[:, 0]))

# Plot outputs
plt.scatter(sales_feature_noCC, sales_noCC[:, 0],  color='black')
plt.plot(sales_feature_noCC, regr_noCC.predict(sales_feature_noCC), color='blue',
         linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Slope: [-2288.68942995]
# Intercept: 225233.551839
# Residual sum of squares: 6092219991.72
# Variance score: 0.18

# %% [markdown]
# ### Look at the fit:

# %%
plt.plot(sales_noCC['CrimeRate'],sales_noCC['HousePrice'],'.',
        sales_noCC['CrimeRate'],crime_model.predict(sales_noCC),'-')

# %% [markdown]
# # Compare coefficients for full-data fit versus no-Center-City fit

# %%
print('Slope:', regr.coef_, '\nIntercept:', regr.intercept_)
print('Slope:', regr_noCC.coef_, '\nIntercept:', regr_noCC.intercept_)
# Out:
# Slope: [-576.90812768]
# Intercept: 176629.408107
# Slope: [-2288.68942995]
# Intercept: 225233.551839

# %% [markdown]
# Visually, the fit seems different, but let's quantify this by examining the estimated coefficients of our original fit and that of the modified dataset with Center City removed.

# %%
crime_model.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+
# |     name    | index |     value      |
# +-------------+-------+----------------+
# | (intercept) |  None | 176626.046881  |
# |  CrimeRate  |  None | -576.804949058 |
# +-------------+-------+----------------+
# [2 rows x 3 columns]

# %%
crime_model_noCC.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+
# |     name    | index |     value      |
# +-------------+-------+----------------+
# | (intercept) |  None | 225204.604303  |
# |  CrimeRate  |  None | -2287.69717443 |
# +-------------+-------+----------------+
# [2 rows x 3 columns]

# %% [markdown]
# Above: We see that for the "no Center City" version, per unit increase in crime, the predicted decrease in house prices is 2,287.  In contrast, for the original dataset, the drop is only 576 per unit increase in crime.  This is significantly different!

# %% [markdown]
# ###High leverage points:
# Center City is said to be a "high leverage" point because it is at an extreme x value where there are not other observations.  As a result, recalling the closed-form solution for simple regression, this point has the *potential* to dramatically change the least squares line since the center of x mass is heavily influenced by this one point and the least squares line will try to fit close to that outlying (in x) point.  If a high leverage point follows the trend of the other data, this might not have much effect.  On the other hand, if this point somehow differs, it can be strongly influential in the resulting fit.
#
# ###Influential observations:
# An influential observation is one where the removal of the point significantly changes the fit.  As discussed above, high leverage points are good candidates for being influential observations, but need not be.  Other observations that are *not* leverage points can also be influential observations (e.g., strongly outlying in y even if x is a typical value).

# %% [markdown]
# # Remove high-value outlier neighborhoods and redo analysis

# %%
sales_nohighend = sales_noCC[sales_noCC[:, 0] < 350000]

# %%
crime_model_nohighend = linear_model.base.LinearRegression()
sales_feature_nohighend = sales_nohighend[:, np.newaxis, 2]
regr_nohighend = crime_model_nohighend.fit(sales_feature_nohighend, sales_nohighend[:, 0])

# %% [markdown]
# Based on the discussion above, a question is whether the outlying high-value towns are strongly influencing the fit.  Let's remove them and see what happens.

# %%
sales_nohighend = sales_noCC[sales_noCC['HousePrice'] < 350000] 
crime_model_nohighend = graphlab.linear_regression.create(sales_nohighend, target='HousePrice', features=['CrimeRate'],validation_set=None, verbose=False)

# %% [markdown]
# ### Do the coefficients change much?

# %%
print('Slope:', regr.coef_, '\nIntercept:', regr.intercept_)
print('Slope:', regr_noCC.coef_, '\nIntercept:', regr_noCC.intercept_)
print('Slope:', regr_nohighend.coef_, '\nIntercept:', regr_nohighend.intercept_)
# Out:
# Slope: [-576.90812768]
# Intercept: 176629.408107
# Slope: [-2288.68942995]
# Intercept: 225233.551839
# Slope: [-1838.56264859]
# Intercept: 199098.85267

# %%
crime_model_noCC.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+
# |     name    | index |     value      |
# +-------------+-------+----------------+
# | (intercept) |  None | 225204.604303  |
# |  CrimeRate  |  None | -2287.69717443 |
# +-------------+-------+----------------+
# [2 rows x 3 columns]

# %%
crime_model_nohighend.get('coefficients')
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
#
# Rows: 2
#
# Data:
# +-------------+-------+----------------+
# |     name    | index |     value      |
# +-------------+-------+----------------+
# | (intercept) |  None | 199073.589615  |
# |  CrimeRate  |  None | -1837.71280989 |
# +-------------+-------+----------------+
# [2 rows x 3 columns]

# %% [markdown]
# Above: We see that removing the outlying high-value neighborhoods has *some* effect on the fit, but not nearly as much as our high-leverage Center City datapoint.
